# %%
import pandas as pd
from pathlib import Path

# %%
import json

# Open and read the JSON file
with open('metadata.repository.2025-05-12.json', 'r') as file:
    data = json.load(file)

# Print the data
# print(data)

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
# {'data_format': 'MAF',
#  'access': 'open',
#  'associated_entities': [{'entity_submitter_id': 'TCGA-W7-A93N-11A-11D-A46P-09',
#    'entity_type': 'aliquot',
#    'case_id': 'd64d8a1b-b31f-4cbb-a586-5ec7f058f0de',
#    'entity_id': '85686adb-8391-489a-bcee-996a70b076bc'},
#   {'entity_submitter_id': 'TCGA-W7-A93N-01A-11D-A46P-09',
#    'entity_type': 'aliquot',
#    'case_id': 'd64d8a1b-b31f-4cbb-a586-5ec7f058f0de',
#    'entity_id': '8176d66c-b535-48fa-b19b-9ae27d35c75c'}],
#  'file_name': 'a167037f-1334-42b9-973b-9b17066fff08.wxs.aliquot_ensemble_masked.maf.gz',
#  'submitter_id': 'f06972af-8243-46a5-89da-a6a92d0dc611',
#  'data_category': 'Simple Nucleotide Variation',
#  'annotations': [{'entity_submitter_id': 'f06972af-8243-46a5-89da-a6a92d0dc611',
#    'notes': 'Variants from SomaticSniper are not included.',
#    'classification': 'Notification',
#    'entity_id': 'e887e862-3fd7-4bfa-8189-ba418c00b592',
#    'created_datetime': '2022-02-28T12:49:46.769826-06:00',
# ...

# %%
out = pd.read_csv(r'gdc_download_20250512_061908.944324\0f13cc5e-1ca3-4cd9-8c1d-07d51eb631a3\70b5014d-329a-4552-80e0-db9372971949.wxs.aliquot_ensemble_masked.maf\70b5014d-329a-4552-80e0-db9372971949.wxs.aliquot_ensemble_masked.maf',
                   sep='\t', header=7)

# %%
out
# Out:
#    Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0      ZBTB8OS          339487  WUGSC     GRCh38       chr1        32633679
# 1     ZMPSTE24           10269  WUGSC     GRCh38       chr1        40268509
# 2      ZMYND12           84217  WUGSC     GRCh38       chr1        42439885
# 3       RNF220           55182  WUGSC     GRCh38       chr1        44644727
# 4        ITLN2          142683  WUGSC     GRCh38       chr1       160951247
# ..         ...             ...    ...        ...        ...             ...
# 75     SULT2A1            6822  WUGSC     GRCh38      chr19        47886192
# 76      ZNF582          147948  WUGSC     GRCh38      chr19        56384902
# 77       TRPM2            7226  WUGSC     GRCh38      chr21        44423665
# 78      ZC3H7B           23264  WUGSC     GRCh38      chr22        41356459
# 79       FAM9B          171483  WUGSC     GRCh38       chrX         9032135
#
# ...

# %%
file_p = Path('clinical_gdc_download_20250512_063537.583479\5ed3dafb-8a63-4f7c-8a37-eb8700afcef8\nationwidechildrens.org_clinical.TCGA-AR-A0TR.xml')

# %%
pd.read_xml(file_p)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\PC\Desktop\code\TOO\.venv_TOO\Lib\site-packages\IPython\core\interactiveshell.py:3670 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[47], line 1
#     pd.read_xml(file_p)
#
#   File c:\Users\PC\Desktop\code\TOO\.venv_TOO\Lib\site-packages\pandas\io\xml.py:1160 in read_xml
#     return _parse(
#
#   File c:\Users\PC\Desktop\code\TOO\.venv_TOO\Lib\site-packages\pandas\io\xml.py:852 in _parse
#     data_dicts = p.parse_data()
#
#   File c:\Users\PC\Desktop\code\TOO\.venv_TOO\Lib\site-packages\pandas\io\xml.py:556 in parse_data
#     self.xml_doc = self._parse_doc(self.path_or_buffer)
#
#   File c:\Users\PC\Desktop\code\TOO\.venv_TOO\Lib\site-packages\pandas\io\xml.py:647 in _parse_doc
#     document = fromstring(
#
#   File src\\lxml\\etree.pyx:3307 in lxml.etree.fromstring
#
#   File src\\lxml\\parser.pxi:1995 in lxml.etree._parseMemoryDocument
#
# ...

# %%
full_clin = pd.read_csv('gdac.broadinstitute.org_BRCA.Merge_Clinical.Level_1.2016012800.0.0\gdac.broadinstitute.org_BRCA.Merge_Clinical.Level_1.2016012800.0.0\BRCA.clin.merged.txt', sep='\t')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\PC\AppData\Local\Temp\ipykernel_17736\4099782732.py:1: SyntaxWarning: invalid escape sequence '\g'
#   full_clin = pd.read_csv('gdac.broadinstitute.org_BRCA.Merge_Clinical.Level_1.2016012800.0.0\gdac.broadinstitute.org_BRCA.Merge_Clinical.Level_1.2016012800.0.0\BRCA.clin.merged.txt', sep='\t')
# C:\Users\PC\AppData\Local\Temp\ipykernel_17736\4099782732.py:1: DtypeWarning: Columns (27,227,230,234,252,254,257,261,267,270,271,273,275,281,283,288,289,290,295) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_clin = pd.read_csv('gdac.broadinstitute.org_BRCA.Merge_Clinical.Level_1.2016012800.0.0\gdac.broadinstitute.org_BRCA.Merge_Clinical.Level_1.2016012800.0.0\BRCA.clin.merged.txt', sep='\t')

# %%
full_clin
# Out:
#                                      admin.batch_number  \
# 0                                             admin.bcr
# 1                               admin.day_of_dcc_upload
# 2                                    admin.disease_code
# 3                                       admin.file_uuid
# 4                             admin.month_of_dcc_upload
# ...                                                 ...
# 3715  patient.tumor_samples.tumor_sample.tumor_locat...
# 3716  patient.tumor_samples.tumor_sample.tumor_necro...
# 3717  patient.tumor_samples.tumor_sample.tumor_nucle...
# 3718    patient.tumor_samples.tumor_sample.tumor_weight
# 3719     patient.tumor_samples.tumor_sample.vessel_used
#
#                                   379.33.0  \
# 0           nationwide children's hospital
# 1                                       21
# 2                                     brca
# 3     4f359141-a351-40ac-a30a-4c27702fa01d
# 4                                        1
# ...

# %%
out_clin = pd.read_csv('gdac.broadinstitute.org_BRCA.Clinical_Pick_Tier1.Level_4.2016012800.0.0\All_CDEs.txt', sep='\t')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\PC\AppData\Local\Temp\ipykernel_17736\4248907654.py:1: SyntaxWarning: invalid escape sequence '\A'
#   out_clin = pd.read_csv('gdac.broadinstitute.org_BRCA.Clinical_Pick_Tier1.Level_4.2016012800.0.0\All_CDEs.txt', sep='\t')

# %%
df = out_clin.T

df.columns = df.iloc[0, :]

df = df.iloc[1:, :]

# %%
df.index.name = df.columns.name

df.columns.name = None

# %%
list(df.columns)
# Out:
# ['bcr_patient_uuid',
#  'patient_id',
#  'vital_status',
#  'days_to_death',
#  'days_to_last_followup',
#  'additional_studies',
#  'additional_surgery_locoregional_procedure',
#  'additional_surgery_metastatic_procedure',
#  'age_at_initial_pathologic_diagnosis',
#  'anatomic_neoplasm_subdivision-2',
#  'anatomic_neoplasm_subdivision-3',
#  'anatomic_neoplasm_subdivision-4',
#  'anatomic_neoplasm_subdivision-5',
#  'anatomic_neoplasm_subdivision',
#  'axillary_lymph_node_stage_method_type',
#  'axillary_lymph_node_stage_other_method_descriptive_text',
#  'b_symptoms',
#  'bcr',
#  'bcr_canonical_reason-2',
#  'bcr_canonical_reason-3',
#  'bcr_canonical_reason',
#  'bcr_followup_barcode',
#  'bcr_followup_uuid',
#  'bcr_patient_canonical_status',
#  'breast_cancer_surgery_margin_status',
#  'breast_carcinoma_estrogen_receptor_status',
#  'breast_carcinoma_immunohistochemistry_er_pos_finding_scale',
#  'breast_carcinoma_immunohistochemistry_pos_cell_score',
# ...
